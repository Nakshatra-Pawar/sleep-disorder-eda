# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = "/Users/nakshatrapawar/Desktop/projects/Health and Sleep relation 2024/Sleep_health_and_lifestyle_dataset.csv"
df = pd.read_csv(file)

# %%
print(df.head())
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.sample(frac=0.1, random_state=42)
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 329        330  Female   53           Engineer             8.5
# 33          34    Male   31             Doctor             6.1
# 15          16    Male   29             Doctor             6.0
# 325        326  Female   53           Engineer             8.5
# 57          58    Male   32             Doctor             6.0
# 239        240    Male   44        Salesperson             6.4
# 76          77    Male   33             Doctor             6.0
# 119        120  Female   37         Accountant             7.2
# 332        333  Female   54           Engineer             8.4
# 126        127    Male   38             Lawyer             7.3
# 233        234    Male   44        Salesperson             6.3
# 39          40    Male   31             Doctor             7.6
# 153        154    Male   39             Lawyer             7.2
# 55          56    Male   32             Doctor             6.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df["Sleep Disorder"].unique()
# Out:
# array([nan, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df.fillna({"Sleep Disorder" : "Normal Sleep"}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
corr_matrix = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(11, 7))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df['Sleep Duration'].plot.hist(bins = 15, title = 'Sleep Duration Distribution')
# Out:
# <Axes: title={'center': 'Sleep Duration Distribution'}, ylabel='Frequency'>

# %%
df['Daily Steps'].plot.box(title = 'Daily Steps Boxplot')
# Out:
# <Axes: title={'center': 'Daily Steps Boxplot'}>

# %%
df.plot.scatter(x='Sleep Duration', y='Stress Level', title='Sleep Duration vs Stress Level')
# Out:
# <Axes: title={'center': 'Sleep Duration vs Stress Level'}, xlabel='Sleep Duration', ylabel='Stress Level'>

# %%
df.groupby('Gender')['Sleep Duration'].mean()
# Out:
# Gender
# Female    7.229730
# Male      7.036508
# Name: Sleep Duration, dtype: float64

# %%
pd.pivot_table(df, 
               values='Heart Rate', 
               index='Sleep Disorder', 
               columns='Gender', 
               aggfunc='mean')
# Out:
# Gender             Female       Male
# Sleep Disorder
# Insomnia        67.305556  73.243902
# Normal Sleep    67.548780  69.897810
# Sleep Apnea     72.402985  77.272727

# %%
df.groupby('Occupation')['Stress Level'].median()
# Out:
# Occupation
# Accountant              4.0
# Doctor                  6.0
# Engineer                3.0
# Lawyer                  5.0
# Manager                 5.0
# Nurse                   6.0
# Sales Representative    8.0
# Salesperson             7.0
# Scientist               7.0
# Software Engineer       5.5
# Teacher                 4.0
# Name: Stress Level, dtype: float64

# %%
df.groupby('Sleep Disorder')['Heart Rate'].mean()
# Out:
# Sleep Disorder
# Insomnia        70.467532
# Normal Sleep    69.018265
# Sleep Apnea     73.089744
# Name: Heart Rate, dtype: float64
